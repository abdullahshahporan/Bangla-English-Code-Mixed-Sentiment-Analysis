# %% [markdown]
# # Module 6 — Final Ensemble and Error Analysis
#
# Combine TF-IDF, Word2Vec, BiLSTM, and Transformer probabilities into one final answer, then categorize real incorrect test predictions.

# %%
from pathlib import Path
import sys
import pandas as pd
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
from src.config import RESULTS_DIR
from src.final_analysis import build_final_analysis

# %%
all_metrics = build_final_analysis()
all_metrics

# %% [markdown]
# ## Review real errors and model disagreements

# %%
errors = pd.read_csv(RESULTS_DIR / 'error_analysis.csv')
display(errors['error_category'].value_counts())
display(errors.head(20))
