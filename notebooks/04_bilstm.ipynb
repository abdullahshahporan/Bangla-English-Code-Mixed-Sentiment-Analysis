# %% [markdown]
# # Module 4 — Bidirectional LSTM
#
# The BiLSTM reads each sentence in both directions. Its vocabulary is built from training text, sequence length comes from the training-set 95th percentile, and early stopping monitors validation Macro F1.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
from src.train_neural_models import TrainingSettings, train_neural_model
settings = TrainingSettings(epochs=12, batch_size=64, patience=3)

# %% [markdown]
# ## Train the stacked Bidirectional LSTM

# %%
bilstm_metrics = train_neural_model('bilstm', settings)
bilstm_metrics
