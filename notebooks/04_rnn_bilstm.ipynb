# %% [markdown]
# # Module 4 — RNN and Bidirectional LSTM
#
# These models preserve token order. The vocabulary is built from training text, sequence length comes from its 95th percentile, and early stopping watches validation Macro F1.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
from src.train_neural_models import TrainingSettings, train_neural_model
settings = TrainingSettings(epochs=12, batch_size=64, patience=3)

# %% [markdown]
# ## M4.1 — Vanilla RNN

# %%
rnn_metrics = train_neural_model('rnn', settings)
rnn_metrics

# %% [markdown]
# ## M4.2 — Stacked Bidirectional LSTM

# %%
bilstm_metrics = train_neural_model('bilstm', settings)
bilstm_metrics
