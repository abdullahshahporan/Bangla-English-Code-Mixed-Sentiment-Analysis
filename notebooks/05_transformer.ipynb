# %% [markdown]
# # Module 5 — Transformer Sentiment Classifier
#
# This encoder uses token embeddings, sinusoidal positions, a padding mask, masked mean pooling, and a four-class output layer.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
from src.train_neural_models import TrainingSettings, train_neural_model
settings = TrainingSettings(epochs=12, batch_size=64, patience=3)

# %%
transformer_metrics = train_neural_model('transformer', settings)
transformer_metrics
